# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tickers = ["BLK", "BAC", "AAPL", "TM", "WMT",
           "JD", "INTU", "MA", "UL", "CVS",
           "DIS", "AMD", "NVDA", "PBI", "TGT"]

# %%
ohlc = yf.download(tickers, period="max")
# Out:
# [*********************100%%**********************]  15 of 15 completed

# %%
prices = ohlc["Adj Close"]
prices.tail()
# Out:
#                   AAPL         AMD        BAC         BLK        CVS  \
# Date
# 2023-08-23  181.119995  109.430000  28.450001  678.770020  66.400002
# 2023-08-24  176.380005  101.800003  28.620001  673.159973  66.489998
# 2023-08-25  178.610001  102.250000  28.500000  675.960022  67.320000
# 2023-08-28  180.190002  102.610001  28.760000  679.000000  67.239998
# 2023-08-29  184.119995  105.919998  29.170000  691.030029  67.129997
#
#                   DIS        INTU         JD          MA        NVDA   PBI  \
# Date
# 2023-08-23  85.830002  500.859985  33.810001  401.059998  471.160004  3.54
# 2023-08-24  82.470001  498.500000  33.020000  397.670013  471.630005  3.49
# 2023-08-25  83.360001  519.049988  32.959999  402.890015  460.179993  3.38
# 2023-08-28  84.160004  518.869995  33.810001  407.440002  468.350006  3.45
# 2023-08-29  84.400002  536.489990  34.500000  411.649994  487.839996  3.46
#
#                    TGT          TM         UL         WMT
# Date
# 2023-08-23  123.209999  165.910004  50.840000  158.100006
# 2023-08-24  124.099998  162.779999  50.560001  156.889999
# 2023-08-25  121.790001  164.460007  50.910000  157.820007
# 2023-08-28  123.430000  167.250000  51.099998  158.720001
# 2023-08-29  126.160004  167.389999  51.310001  160.050003

# %%
import pypfopt
pypfopt.__version__
# Out:
# '1.5.5'

# %%
from pypfopt import risk_models, expected_returns
from pypfopt import plotting

mu = expected_returns.capm_return(prices)
S = risk_models.semicovariance(prices)

# %%
S
# Out:
#           AAPL       AMD       BAC       BLK       CVS       DIS      INTU  \
# AAPL  0.065158  0.042513  0.022394  0.011967  0.016865  0.020335  0.020848
# AMD   0.042513  0.114020  0.033287  0.018454  0.022384  0.028350  0.027891
# BAC   0.022394  0.033287  0.054363  0.016587  0.018894  0.023083  0.017444
# BLK   0.011967  0.018454  0.016587  0.020485  0.008313  0.010862  0.011965
# CVS   0.016865  0.022384  0.018894  0.008313  0.037047  0.017179  0.011921
# DIS   0.020335  0.028350  0.023083  0.010862  0.017179  0.046141  0.015081
# INTU  0.020848  0.027891  0.017444  0.011965  0.011921  0.015081  0.046513
# JD    0.005177  0.008850  0.004804  0.004480  0.003209  0.004482  0.005306
# MA    0.008544  0.013415  0.012656  0.010138  0.005890  0.007859  0.008037
# NVDA  0.023774  0.039144  0.020848  0.017614  0.012915  0.017339  0.022903
# PBI   0.019606  0.028380  0.023819  0.011816  0.016777  0.020976  0.014203
# TGT   0.020211  0.027642  0.021502  0.010109  0.018365  0.019949  0.014832
# TM    0.015882  0.022047  0.015866  0.008723  0.010561  0.013270  0.011137
# UL    0.013020  0.017761  0.013357  0.007510  0.009920  0.011610  0.009762
# WMT   0.017119  0.020414  0.016357  0.006280  0.015324  0.016363  0.011505
#
#             JD        MA      NVDA       PBI       TGT        TM        UL  \
# AAPL  0.005177  0.008544  0.023774  0.019606  0.020211  0.015882  0.013020
# AMD   0.008850  0.013415  0.039144  0.028380  0.027642  0.022047  0.017761
# BAC   0.004804  0.012656  0.020848  0.023819  0.021502  0.015866  0.013357
# BLK   0.004480  0.010138  0.017614  0.011816  0.010109  0.008723  0.007510
# CVS   0.003209  0.005890  0.012915  0.016777  0.018365  0.010561  0.009920
# DIS   0.004482  0.007859  0.017339  0.020976  0.019949  0.013270  0.011610
# INTU  0.005306  0.008037  0.022903  0.014203  0.014832  0.011137  0.009762
# JD    0.015450  0.004580  0.008003  0.006479  0.004005  0.003391  0.002832
# MA    0.004580  0.013777  0.012353  0.008881  0.006995  0.006301  0.005745
# NVDA  0.008003  0.012353  0.061927  0.017035  0.015353  0.013431  0.010285
# PBI   0.006479  0.008881  0.017035  0.055078  0.019036  0.013148  0.011425
# TGT   0.004005  0.006995  0.015353  0.019036  0.039835  0.012628  0.011379
# TM    0.003391  0.006301  0.013431  0.013148  0.012628  0.025910  0.009579
# UL    0.002832  0.005745  0.010285  0.011425  0.011379  0.009579  0.019664
# WMT   0.002338  0.004191  0.010364  0.015191  0.019168  0.009484  0.008882
#
#            WMT
# AAPL  0.017119
# AMD   0.020414
# BAC   0.016357
# BLK   0.006280
# CVS   0.015324
# DIS   0.016363
# INTU  0.011505
# JD    0.002338
# MA    0.004191
# NVDA  0.010364
# PBI   0.015191
# TGT   0.019168
# TM    0.009484
# UL    0.008882
# WMT   0.032249

# %%
# Plot efficient frontier with Monte Carlo sim
from pypfopt.efficient_frontier import EfficientFrontier
ef = EfficientFrontier(mu, S)

fig, ax = plt.subplots()
plotting.plot_efficient_frontier(ef, ax=ax, show_assets=False)

# # Find and plot the tangency portfolio
# ef2 = EfficientFrontier(mu, S)
# ef2.max_sharpe()
# ret_tangent, std_tangent, _ = ef2.portfolio_performance()

# # Plot random portfolios
# ax.scatter(stds, rets, marker=".", c=sharpes, cmap="viridis_r")

# Format
ax.set_title("Efficient Frontier with random portfolios")
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/k7/v1ttxlvj0h5g7gfj4b45b6k40000gn/T/ipykernel_7002/2618968018.py:19: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
